# %%
# A1: There are 2 time slots in a day: Morning and Noon
# A2: Each exam will be of 3 hours
# A3: Morning Slot = 9am - 12pm
# A4: Evening Slot = 2pm - 5pm
# A5: It is possible that not all classrooms are used in a single day
# A6: The higher the fitness score, the better the solution (Our goal is to maximize fitness value)
# A7: Any day with exams scheduled will have exam at both morning and noon

# Importing Libraries

import collections
import csv
import random
import statistics
from copy import deepcopy
from colorama import Fore, Back
from numpy import random
from numpy.random import randint

# Globals
# Sample Dataset (not indicative of real world)
# Total of 24 rooms (12 for each block)

room_names = ['B-004', 'B-003', 'B-002', 'B-001', 'B-104', 'B-103', 'B-102', 'B-101','B-204', 'B-203', 'B-202', 'B-201', 
              'C-004', 'C-003', 'C-002', 'C-001', 'C-104', 'C-103', 'C-102', 'C-101','C-204', 'C-203', 'C-202', 'C-201']

# No exams on weekends

total_days = ['Week 1 : Mon', 'Week 1 : Tue', 'Week 1 : Wed', 'Week 1 : Thu', 'Week 1 : Fri', 'Week 1 : Sat', 'Week 1 : Sun',
              'Week 2 : Mon', 'Week 2 : Tue', 'Week 2 : Wed', 'Week 2 : Thu', 'Week 2 : Fri', 'Week 2 : Sat', 'Week 2 : Sun']

# Each exam must have an invigilator.

classrooms = collections.namedtuple('classroom', 'room_name morning invig_morning noon invig_noon')

# Classes will be used to store the data of each exam

# Batch Data Class
# This class will contain the name of batches along with the list containing the courses the batch has that year

class BatchData:
    def __init__(self, name, courses):
        self.name = name
        self.courses = []
        self.courses.append(courses)

    def add_course(self, course):
        self.courses.append(course)

    def __repr__(self):                                                # Returns string representation
        output = "Batch: " + self.name + "\t" + "Courses: " + str(self.courses) + "\n"
        return output

def add_batch(batch_list, name, cc):                               # Add a course for a specific batch in the list

    for batch in batch_list:
        if batch.name == name:
            if cc not in batch.courses:                              # To cater repeated value
                batch.add_course(cc)
            return

    new_batch = BatchData(name, cc)
    batch_list.append(new_batch)

# Schedule Class

# This class' object will act as a single solution for the problem. It consists of days and a collection of room info, time slots and
# teachers on invigilation duties. We have created a dictionary to store a collection corresponding each day of the week.
# Each day will have a list of classes that will be held on that day.

class Schedule:
    def __init__(self, days=dict(), fitness=0):
        self.days = days
        self.fitness = fitness

        for day in total_days:
            self.days[day] = []


# This function loads each csv file into appropriate data types for future use.

def load_data():
    courses = []

    with open("data/courses.csv") as csv_file:            # Sample Dataset
        csv_reader = csv.reader(csv_file, delimiter=',')  # Loading courses
        for row in csv_reader:
            code_title = row[0]
            courses.append(code_title)

    # -------------------- #

    teacher = []
    

    with open("data/teachers.csv") as csv_file:           # Sample Dataset
        csv_reader = csv.reader(csv_file, delimiter=',')  # Loading teachers
        for row in csv_reader:
            if len(row) > 0:
                name = row[0]
                teacher.append(name)

    # -------------------- #

    batch_list = []
    
    with open("data/batchCourse.csv") as csv_file:        # Sample Dataset
        csv_reader = csv.reader(csv_file, delimiter=',')  # Reading students and their courses
        line = 0
        for row in csv_reader:
            if line != 0:
                name = row[0]
                cc = row[1]
                add_batch(batch_list, name, cc)
            line += 1

    return courses, teacher, batch_list                 # Returning all data


# Utility Functions

# Printing Functions

def print_custom_class(classes_list):
    for _class in classes_list:
        morning_paper = _class.morning.ljust(6)
        m_invigilator = _class.invig_morning.ljust(18)
        noon_paper = _class.noon.ljust(6)
        n_invigilator = _class.invig_noon.ljust(18)

        print(Back.CYAN + "   " + Fore.BLACK + _class.room_name + "  " + Back.RESET + Fore.RESET, sep='', end='')
        print(Back.GREEN + "  " + Fore.BLACK + morning_paper + "  " + Back.RESET + Fore.RESET, sep='', end='')
        print(Back.YELLOW + "  " + Fore.BLACK + m_invigilator + "  " + Back.RESET + Fore.RESET, sep='', end='')
        print(Back.GREEN + "  " + Fore.BLACK + noon_paper + "  " + Back.RESET + Fore.RESET, sep='', end='')
        print(Back.YELLOW + "  " + Fore.BLACK + n_invigilator + "  " + Back.RESET + Fore.RESET)


def print_custom_schedule(schedule):
    for day in schedule.days:
        if len(schedule.days[day]) > 0:
            print()
            print(Back.BLACK + "                                                                         " + Back.RESET)
            print(
                Back.BLACK + Fore.WHITE + "                               " + day + "                              " + Fore.RESET + Back.RESET)
            print(Back.BLACK + "                                                                         " + Back.RESET)
            print(Back.BLACK + "                                                                         " + Back.RESET)

            print(Back.BLACK + Fore.WHITE + " Room No "+"  9 - 12    Morning Invigilator   2 - 5     Evening Invigilator "+ Back.RESET)
            print(Back.BLACK + "                                                                         " + Back.RESET)

            print_custom_class(schedule.days[day])


def print_classes_list(classes_list):
    for _class in classes_list:
        print(_class)


def print_schedule(schedule):
    for day in schedule.days:
        if len(schedule.days[day]) > 0:
            print("\nDay: ", day)
            print_classes_list(schedule.days[day])


def print_population(population):
    count = 1
    for schedule in population:

        print("Schedule #", count, "\n")
        print("Fitness: ", schedule.fitness)
        for day in schedule.days:
            print("\nDay: ", day, "\n\n")
            print_classes_list(schedule.days[day])
            print("\n")

        count += 1


## Generate Population

# This function is used to generate set of random solutions.

def generate_population(population_size, courses, teachers):
    new_pop = []

    for i in range(0, population_size):
        schedule = Schedule(dict())

        for day in total_days:

            visited_indexes = []
            total_classrooms = random.randint(0, len(room_names))  
                                                            # Classrooms = room_name, morning, invig_morning, noon, invig_noon

            for j in range(total_classrooms):

                index = random.randint(0, len(room_names))  # Generating that number of classrooms

                while index in visited_indexes:
                    index = random.randint(0, len(room_names))

                room = room_names[index]
                visited_indexes.append(index)

                index1 = random.randint(0, len(courses))    # Randomly picking morning course
                m_course = courses[index1]

                index2 = random.randint(0, len(teachers))   # Randomly picking invigilator for morning
                m_invig = teachers[index2]

                index3 = random.randint(0, len(courses))    # Randomly picking noon course
                n_course = courses[index3]

                index4 = random.randint(0, len(teachers))   # Randomly picking invigilator for noon
                n_invig = teachers[index4]

                schedule.days[day].append(
                    classrooms(
                        room_name=room,
                        morning=m_course,
                        invig_morning=m_invig,
                        noon=n_course,
                        invig_noon=n_invig
                    )
                )

        new_pop.append(schedule)

    return new_pop

# Generate parameters for calculating fitness 
# (Each parameter is a value for a particular constraint which is used to calculate fitness)

def hconstraint_all_courses(schedule, courses):         # Hard Const 1 = Exam scheduled for every course

    bool_check = False

    exam_list = []
    

    for day in schedule.days:                           # Getting list of all exams in the schedule week
        class_list = schedule.days[day]

        for _class in class_list:                       # Examining every classroom assigned
            m_exam = _class.morning
            n_exam = _class.noon
            

            if m_exam not in exam_list:
                exam_list.append(m_exam)

            if n_exam not in exam_list:
                exam_list.append(n_exam)

    exam_codes = []                                     # List of all exams

    for course in courses:
        exam_codes.append(course)                         # Gets list of all exam codes of all courses

    missing = 0
    for code in exam_codes:
        if code not in exam_list:                       # Comparing the two lists
            missing += 1                                # Number of courses not listed

    if missing == 0:                                    # If the constraint is satisfied completely
        bool_check = True

    num = (1 / (1 + missing))

    return num, bool_check

def hconstraint_clashing_exams(schedule, course_allocation):  # Hard Const 2 : Student has 1 exam at a time

    exam_list = []

    for day in schedule.days:                                 # Getting list of all exams in this schedule
        classes_list = schedule.days[day]

        for _class in classes_list:                           # Storing all exams for that day
            exam_list.append(_class.morning)
            exam_list.append(_class.noon)

    exam_counts = dict(collections.Counter(exam_list))

    clashes = 0
    batch_names_clashes = []
    bool_check = False

    for day in schedule.days:                                 # Getting list of classrooms for every day
        classes_list = schedule.days[day]

        morning_list = []
        noon_list = []

        for _class in classes_list:                           # Getting lists of all exams on morning and noon
            morning_list.append(_class.morning)
            noon_list.append(_class.noon)

        for batch in course_allocation:                   # Examining all students and their allocated courses
            course_list = batch.courses
            name = batch.name

            clash_flag = False                                # Checking if record clashes for a student

            count = 0
            for course in morning_list:
                if course in course_list:
                    if course in exam_counts.keys():
                        if exam_counts[course] == 1:          # Exam only at this specific time
                            count += 1                        # Counting clashes in morning for a student

            if name not in batch_names_clashes:
                if count > 1:
                    clash_flag = True
                    clashes += 1
                    batch_names_clashes.append(name)

            count = 0
            for course in noon_list:
                if course in course_list:
                    if course in exam_counts.keys():
                        if exam_counts[course] == 1:
                            count += 1

            if name not in batch_names_clashes:
                if count > 1 and not clash_flag:
                    clashes += 1                              # Counting clashes in evening for a student
                    batch_names_clashes.append(name)

    if clashes == 0:                                          # If the constraint is satisfied completely
        bool_check = True

    num = (1 / (1 + clashes))

    return num, bool_check

def hconstraint_teachers_sametime(schedule):                  # Hard Const 3 : No teacher clashes at the same time

    clashes = 0
    bool_check = False

    for day in schedule.days:
        classes_list = schedule.days[day]
        morning_list = []
        noon_list = []

        for _class in classes_list:                           # Getting lists of all teachers on morning and noon
            morning_list.append(_class.invig_morning)
            noon_list.append(_class.invig_noon)

        dup_count_morning = dict(collections.Counter(morning_list))  # Getting the number of duplicate entries
        dup_count_noon = dict(collections.Counter(noon_list))

        for value in dup_count_morning.values():
            if value > 1:
                clashes += 1                                         # Calculating the number of clashes

        for value in dup_count_noon.values():
            if value > 1:
                clashes += 1

    if clashes == 0:                                                 # If the constraint is satisfied completely
        bool_check = True

    num = (1 / (1 + clashes))

    return num, bool_check
    
def hconstraint_course_scheduled_once(schedule):                     # Hard Const 4: One course must be scheduled once only

    repeated = 0
    scheduled = []
    bool_check = False

    for day in schedule.days:
        classes_list = schedule.days[day]

        for _class in classes_list:                                  # Getting lists of all courses on morning and noon
            scheduled.append(_class.morning)
            scheduled.append(_class.noon)

    dup_counts = dict(collections.Counter(scheduled))                # Counting the courses scheduled more than once

    for value in dup_counts.values():
        if value > 4:
            repeated += 1

    if repeated == 0:                                                # If the constraint is satisfied completely
        bool_check = True

    num = (1 / (1 + repeated))

    return num, bool_check


def sconstraint_less_days(schedule):                                 # Soft Const 1: Schedule in less days

    no_days = 0

    for day in schedule.days:
        classes_list = schedule.days[day]                            # Getting schedule for each day

        if not classes_list:                                         # Checks if nothing is scheduled
            no_days += 1

    n = len(total_days) - no_days
    num = (1 / (1 + n))

    return num, no_days                                              # If empty days are more = Solution is better

def sconstraint_equal_invig_duties(schedule):                        # Soft Const 1: Schedule in less days
    classes_list = []
    count_invig_duties = {}
    for day in schedule.days:
        classes_list = schedule.days[day]

    for _class in classes_list:                                      # Getting a counter list for invigilation duties
        count_invig_duties[_class.invig_morning] = 0
        count_invig_duties[_class.invig_noon] = 0
    
    for _class in classes_list:                                      # Updating the counter list for invigilation duties
        count_invig_duties[_class.invig_morning] += 1
        count_invig_duties[_class.invig_noon] += 1
    
    L = list(count_invig_duties.values())                            # List of all counts of invigilation duties
    
    if len(L) >= 2:
        num = 1 / (1 + statistics.stdev(L))
    else: 
        num = 0
    
    return num

# Checking if all hard constraints are satisfied
def constraints_satisfied_check(schedule, courses, course_allocation):
    hc1, hb1 = hconstraint_all_courses(schedule, courses)
    hc2, hb2 = hconstraint_clashing_exams(schedule, course_allocation)
    hc3, hb3 = hconstraint_teachers_sametime(schedule)
    hc4, hb4 = hconstraint_course_scheduled_once(schedule)
    _, sb2 = sconstraint_less_days(schedule)
    sb3 = sconstraint_equal_invig_duties(schedule)

                                                     # all hard constraints satisfied
    if hb1 and hb2 and hb3 and hb4:
                                                     # at least one soft constraint (2 already satisfied by default)
        if sb2 > 0 or sb3:
            return True

    return False


def print_check():
    print(Back.BLACK + "                                                                         " + Back.RESET)
    print(
        Back.BLACK + Fore.WHITE + "                             " + "HARD CONSTRAINTS" + "                            " + Fore.RESET + Back.RESET)
    print(Back.BLACK + "                                                                         " + Back.RESET)

    h1 = "1: Exam is scheduled for each course = " + '\u2705' + '\u2705'
    h2 = "2: Student cannot give more than one exam at a time = " + '\u2705' + '\u2705'
    h3 = "3: Teacher invigilates one exam at a time = " + '\u2705' + '\u2705'
    h4 = "4: Exam wont be held on weekends = " + '\u2705' + '\u2705'
    h5 = "5: Use at max 24 classrooms = " + '\u2705' + '\u2705'

    hc1 = h1.ljust(58)
    hc2 = h2.ljust(58)
    hc3 = h3.ljust(58)
    hc4 = h4.ljust(58)
    hc5 = h5.ljust(58)

    print(Back.RED + Fore.WHITE + "  " + hc1 + "          " + Fore.RESET + Back.RESET)
    print(Back.RED + Fore.WHITE + "  " + hc2 + "          " + Fore.RESET + Back.RESET)
    print(Back.RED + Fore.WHITE + "  " + hc3 + "          " + Fore.RESET + Back.RESET)
    print(Back.RED + Fore.WHITE + "  " + hc4 + "          " + Fore.RESET + Back.RESET)
    print(Back.RED + Fore.WHITE + "  " + hc5 + "          " + Fore.RESET + Back.RESET)

    print()
    print(Back.BLACK + "                                                                         " + Back.RESET)
    print(
        Back.BLACK + Fore.WHITE + "                             " + "SOFT CONSTRAINTS" + "                            " + Fore.RESET + Back.RESET)
    print(Back.BLACK + "                                                                         " + Back.RESET)

    s1 = "1: Exam is scheduled in less days = " + '\u2705' + '\u2705'
    s2 = "2: Almost equal number of invigilation duties = " + '\u2705' + '\u2705'

    sc1 = s1.ljust(60)
    sc2 = s2.ljust(60)

    print(Back.BLUE + Fore.BLACK + "  " + sc1 + "        " + Fore.RESET + Back.RESET)
    print(Back.BLUE + Fore.BLACK + "  " + sc2 + "        " + Fore.RESET + Back.RESET)


def constraints_satisfied_print(schedule, courses, course_allocation):
    hc1, hb1 = hconstraint_all_courses(schedule, courses)
    hc2, hb2 = hconstraint_clashing_exams(schedule, course_allocation)
    hc3, hb3 = hconstraint_teachers_sametime(schedule)
    hc4, hb4 = hconstraint_course_scheduled_once(schedule)
    sc2, sc_days = sconstraint_less_days(schedule)
    sb3 = sconstraint_equal_invig_duties(schedule)

    print("\n---------------------------------\n")
    print("Hard constraints: \n")

    print("hc1 = ", hc1, " hc2 = ", hc2, " hc3 = ", hc3, " hc4 = ", hc4, " sc2 = ", sc2)

    print("An exam will be scheduled for each course: ", end='')

    if hb1:
        print('\u2705')
    else:
        print('\u2716')

    print("A student cannot give more than 1 exam at a time: ", end='')

    if hb2:
        print('\u2705')
    else:
        print('\u2716')

    print("A teacher cannot invigilate two exams at the same time: ", end='')
    if hb3:
        print('\u2705')
    else:
        print('\u2716')

    print("Each course is scheduled atleast once: ", end='')
    if hb4:
        print('\u2705')
    else:
        print('\u2716')

    print("\n\nSoft constraints: \n")

    print("Equal number of invigilation duties: " + '\u2705')

    
    print("Schedule in less days: ", end='')

    if sc_days > 0:
        print('\u2705')
    else:
        print('\u2716')
    print()
    print()

# Utlity functions for GA

def calculate_fitness(population, courses, course_allocation):
    for schedule in population:                                  # For each schedule in a population
        hc1, hb1 = hconstraint_all_courses(schedule, courses)
        hc2, hb2 = hconstraint_clashing_exams(schedule, course_allocation)
        hc3, hb3 = hconstraint_teachers_sametime(schedule)
        hc4, hb4 = hconstraint_course_scheduled_once(schedule)
        # hc5, hb5 = hconstraint_course_scheduled_once(schedule, courses)
        sc2, empty_days = sconstraint_less_days(schedule)
        sc3 = sconstraint_equal_invig_duties(schedule)

        fitness = hc1 + hc2 + hc3 + hc4 + sc2 + sc3              # Calculating the fitness of the schedule
        schedule.fitness = fitness                               # Adding the fitness to the class

        if empty_days > 7:                                       # No schedule with too many empty days added
            schedule.fitness -= 2

    return population

def get_fitness(schedule):                                       # Returning fitness
    return schedule.fitness

def two_fittest_schedules(population):                           # Selecting two fittest solutions (schedules)
    pop = deepcopy(population)
    pop.sort(key=get_fitness, reverse=True)                      # Sorts in descending order
    return pop[0], pop[1]

def parent_selection(population):                                # Roulette Wheel Selection

    parents = []
    total_fitness = 0

    for schedule in population:
        total_fitness += schedule.fitness

    highest, second_highest = two_fittest_schedules(population)  # Getting two fittest solutions
    parents.append(highest)
    parents.append(second_highest)
    fitness_sum = 0

    while len(parents) < len(population):

        individual = random.randint(0, len(population))          # Getting a random index
        fitness_sum += population[individual].fitness
        if fitness_sum >= total_fitness:                         # Individual chosen based on its probability
            if population[individual] not in parents:
                parents.append(deepcopy(population[individual]))

    return parents

def mix_days(parent_a, parent_b):                                # Generating new schedule

    no_days_to_mix = randint(1, len(total_days))                 # Random crossover point
    child1 = Schedule()
    child2 = deepcopy(child1)

    i = 0
    for day in total_days:

        if i < no_days_to_mix:                                  # Taking that # of days from first parent
            classes_list_a = parent_a.days[day]
            classes_list_b = parent_b.days[day]

            child1.days[day] = deepcopy(classes_list_a)
            child2.days[day] = deepcopy(classes_list_b)

        else:                                                   # Taking rest of days from second parent
            classes_list_a = parent_a.days[day]
            classes_list_b = parent_b.days[day]

            child1.days[day] = deepcopy(classes_list_b)
            child2.days[day] = deepcopy(classes_list_a)

        i += 1

    return child1, child2

def mutate_schedule(schedule, mutation_probability, courses, teachers):  # Applying mutation on chromosomes

    if randint(0, 100) <= mutation_probability * 100:                    # Checking prob for mutation
        random_days = randint(0, len(total_days))                        # Selecting random no of days to change

        for i in range(0, random_days):
                                                                         # Choosing a random day
            idx = randint(0, len(total_days))
            day = total_days[idx]

            classes_list = schedule.days[day]

                                                                         # If it had assigned classes/exams
            if len(classes_list) > 0:
                if randint(0, 2) == 1:
                    for j in range(0, len(classes_list)):                # Will change one class at a time

                        if randint(0, 2) == 1:                           # 50% probabilty for mutation
                            index = random.randint(0, len(courses))      # Randomly replacing course
                            morning = courses[index]

                            index = random.randint(0, len(teachers))     # Randomly replacing invigilator
                            invig_morning = teachers[index]

                            index = random.randint(0, len(courses))      # Randomly replacing course
                            noon = courses[index]

                            index = random.randint(0, len(teachers))     # Randomly replacing invigilator
                            invig_noon = teachers[index]

                                                                         # Updating the values
                            classes_list[j] = classes_list[j]._replace(morning=morning, invig_morning=invig_morning)
                            classes_list[j] = classes_list[j]._replace(noon=noon, invig_noon=invig_noon)
                else:
                    classes_list.clear()

                                                       # If that day was empty, then assign it some classes/exams
            else:
                visited_indexes = []
                total_classrooms = random.randint(0,5)   # Classrooms = room_name, morning, invig_morning, noon, invig_noon

                for j in range(total_classrooms):

                    index = random.randint(0, len(room_names))       # Generating that number of classrooms

                    while index in visited_indexes:
                        index = random.randint(0, len(room_names))

                    room = room_names[index]
                    visited_indexes.append(index)

                    index = random.randint(0, len(courses))   # Randomly picking morning course
                    m_course = courses[index]

                    index = random.randint(0, len(teachers))  # Randomly picking invigilator for morning
                    m_invig = teachers[index]

                    index = random.randint(0, len(courses))   # Randomly picking noon course
                    n_course = courses[index]

                    index = random.randint(0, len(teachers))  # Randomly picking invigilator for noon
                    n_invig = teachers[index]

                    classes_list.append(
                        classrooms(
                            room_name=room,
                            morning=m_course,
                            invig_morning=m_invig,
                            noon=n_course,
                            invig_noon=n_invig
                        )
                    )

    return schedule                                           # Returning the mutated schedule

def apply_crossover(population, crossover_probability):       # Applying crossover

    crossovered_population = []

                                                              # Equal length crossover
    while len(crossovered_population) < len(population):
        if randint(0, 100) <= crossover_probability * 100:
            parent_a, _ = two_fittest_schedules(population)   # Selecting fittest parent

                                                              # Selecting a random parent
            index_b = randint(0, len(population))
            parent_b = population[index_b]

            child1, child2 = mix_days(parent_a, parent_b)

            crossovered_population.append(deepcopy(child1))
            crossovered_population.append(deepcopy(child2))

    return crossovered_population

def apply_mutation(population, mutation_probability, courses, teachers):
    mutated_population = []

    for schedule in population:
        s = mutate_schedule(schedule, mutation_probability, courses, teachers)
        mutated_population.append(deepcopy(s))

    return mutated_population

# Genetic Algorithm

# This is the main implementation of the Genetic Algorithm

def genetic_algo(population_size, max_generations, crossover_probability, mutation_probability, courses, teachers,
                 course_allocation):

    best_solution = None

                                              # Generating a list of schedules
    population = [generate_population(population_size, courses, teachers)]

                                              # For seeing if algorithm is unable to optimise further
    
    stagnant = 0
    reset_count = 0
    solutions_list = []
    prev_best = None # Fitness Value of the previous best solution of the population from the previous generation

    for i in range(max_generations):

                                              # Evaluating fitness
        pop = calculate_fitness(population[0], courses, course_allocation)

                                              # Selecting parents through roulette wheel selection
        parents = parent_selection(deepcopy(pop))

                                              # Applying crossover
        crossover_population = apply_crossover(parents, crossover_probability)
        calculate_fitness(crossover_population, courses, course_allocation)

                                              # Applying mutation
        mutated_population = apply_mutation(crossover_population, mutation_probability, courses, teachers)
        calculate_fitness(mutated_population, courses, course_allocation)

                                              # Finding fittest candidate
        schedule1, _ = two_fittest_schedules(mutated_population)

        if best_solution is None:
            stagnant = 0
            best_solution = deepcopy(schedule1)

        elif schedule1.fitness > best_solution.fitness:
            stagnant = 0
            best_solution = deepcopy(schedule1)

        if best_solution.fitness == prev_best:
            stagnant += 1

        prev_best = deepcopy(best_solution.fitness)

        if constraints_satisfied_check(best_solution, courses, course_allocation):
            constraints_satisfied_print(best_solution, courses, course_allocation)
            print()
            print(Back.BLACK + "                                                                         " + Back.RESET)
            print(
                Back.BLACK + Fore.WHITE + "                             SOLUTION FOUND!!!!                          " + Fore.RESET + Back.RESET)
            print(Back.BLACK + "                                                                         " + Back.RESET)
            print()
            return best_solution

        # No further optimisation for this # of generations
        if stagnant == 50:
            if reset_count < 3:
                print(
                    "\n-------------------\nAlgorithm is unable to optimise further. Starting over with a new random population.\n-------------------\n")
                solutions_list.append(deepcopy(best_solution))

                i = 0
                stagnant = 0
                reset_count += 1

                pop = generate_population(population_size, courses, teachers)
                best_solution = None
                population.clear()
                population.append(pop)
                continue

            else:
                print(
                    "\nAlgorithm unable to optimise further. Terminating program and returning best solution upto now.\n")
                best, _ = two_fittest_schedules(solutions_list)
                return best

        else:
            # Generating new population
            population.clear()
            population.append(mutated_population)

        if i % 100 == 0:
            print("Current generation so far: ", i)
            print("Best solution so far: \nFitness: ", best_solution.fitness)
            print_schedule(best_solution)
            constraints_satisfied_print(best_solution, courses, course_allocation)

        print(i, "- Fitness of best solution: ", best_solution.fitness, "\t( Fitness of local best solution: ",
              schedule1.fitness, ")", "\t( Stagnation: ", stagnant, ")")

    return best_solution

# Main function

# The main entry point for this module
def main():
    courses, teachers, course_allocation = load_data()

    population_size = random.randint(50, 200)          # number of solutions in a population
    max_generations = random.randint(100, 1000)        # how long to iterate

    crossover_probability = 1
    mutation_probability = 0.6

    print('\n\n--- Generated Parameters -----')
    print('Population size......: {}'.format(population_size))
    print('Number of generations: {}'.format(max_generations))
    print('Crossover probability: {}'.format(crossover_probability))
    print('Mutation probability: {}'.format(mutation_probability))

    res = genetic_algo(population_size, max_generations, crossover_probability, mutation_probability, courses, teachers,
                       course_allocation)

    print_custom_schedule(res)                        # Printing the final schedule
    print_check()                                     
    print()


if __name__ == "__main__":
    main()
# Out:
# --- Generated Parameters -----
# Population size......: 56
# Number of generations: 181
# Crossover probability: 1
# Mutation probability: 0.6
# Current generation so far:  0
# Best solution so far:
# Fitness:  3.2371212121212123
#
# Day:  Week 1 : Mon
# classroom(room_name='C-004', morning='IMIT5204', invig_morning='Eric Humphries', noon='IMIT3204', invig_noon='Sidney Nunn')
# classroom(room_name='B-202', morning='IMIT3203', invig_morning='Alistair Ashley', noon='BCCS4204', invig_noon='Andrew Lawton')
# classroom(room_name='C-002', morning='BCCS4203', invig_morning='Sunil McLeod', noon='BCCS3203', invig_noon='Jeff Vernon')
# classroom(room_name='C-202', morning='IMIT4201', invig_morning='Christine Tompkins', noon='IMG3202', invig_noon='Phil Randall')
# classroom(room_name='B-004', morning='IMIT4204', invig_morning='Jess Shah', noon='IMG5202', invig_noon='Marta Arnold')
# classroom(room_name='B-103', morning='IMG5203', invig_morning='Mohammad Walter', noon='IMIT2203', invig_noon='Vincent Moody')
# classroom(room_name='C-102', morning='IMIT5201', invig_morning='Erika Burke', noon='BCCS3202', invig_noon='Toni Mullins')
# classroom(room_name='B-001', morning='IMG1103', invig_morning='Mitchell Walter', noon='IMG2202', invig_noon='Mitchell Walter')
#
# Day:  Week 1 : Tue
# classroom(room_name='C-004', morning='IMG5204', invig_morning='Hammad Majeed', noon='IMG4204', invig_noon='Pamela Healey')
# classroom(room_name='C-202', morning='BCCS3205', invig_morning='Leah Atkins', noon='BCCS3202', invig_noon='Faisal Cheema')
# classroom(room_name='B-103', morning='BCCS4204', invig_morning='Behjat Zuhaira', noon='IMIT5204', invig_noon='Cesar Harper')
# classroom(room_name='B-201', morning='IMG1105', invig_morning='Ali Hurley', noon='IMIT5205', invig_noon='Allan Frederick')
# classroom(room_name='B-104', morning='IMIT4205', invig_morning='Darla Hicks', noon='BCCS4201', invig_noon='Dianne Foley')
# classroom(room_name='B-002', morning='IMG5203', invig_morning='Laurie Castillo', noon='BCCS4201', invig_noon='Paul Winter')
# classroom(room_name='C-204', morning='IMIT1102', invig_morning='Laurie Castillo', noon='IMG3204', invig_noon='Derrick Spence')
# classroom(room_name='C-101', morning='BCCS2205', invig_morning='Eric Humphries', noon='IMG3201', invig_noon='Edna Todd')
# classroom(room_name='C-003', morning='IMIT3205', invig_morning='Horace Gardiner', noon='BCCS1103', invig_noon='Shoaib Mehboob')
# classroom(room_name='C-002', morning='IMIT3204', invig_morning='Valerie Street', noon='IMG5203', invig_noon='Aimee Pierson')
#
# Day:  Week 1 : Wed
# classroom(room_name='C-002', morning='IMG2203', invig_morning='Jeremy Romero', noon='BCCS1102', invig_noon='Dean Wade')
# classroom(room_name='B-104', morning='IMIT2205', invig_morning='Sebastian Lock', noon='IMIT1105', invig_noon='Julie Higgins')
# classroom(room_name='C-004', morning='IMIT5202', invig_morning='Derrick Spence', noon='BCCS3201', invig_noon='Jon Curtis')
# classroom(room_name='C-204', morning='BCCS3205', invig_morning='Katrina James', noon='IMG3205', invig_noon='Jeffery Perez')
# classroom(room_name='B-101', morning='BCCS4201', invig_morning='Julie Higgins', noon='IMIT2205', invig_noon='Laurie Castillo')
# classroom(room_name='C-203', morning='IMG4201', invig_morning='Veronica Hooper', noon='IMIT3201', invig_noon='Arshad Islam')
# classroom(room_name='C-202', morning='IMG5201', invig_morning='Jody Hardman', noon='IMIT4202', invig_noon='Ali Hurley')
# classroom(room_name='B-102', morning='IMG2204', invig_morning='Toni Mullins', noon='IMG5201', invig_noon='Usman Dobson')
# classroom(room_name='C-003', morning='IMG1102', invig_morning='Noor ul Ain', noon='IMIT5204', invig_noon='Usman Dobson')
# classroom(room_name='B-203', morning='IMIT5203', invig_morning='Kerri Huynh', noon='IMIT1102', invig_noon='David Arias')
#
# Day:  Week 1 : Thu
# classroom(room_name='B-102', morning='IMIT3202', invig_morning='Jennie McKenna', noon='BCCS4204', invig_noon='Ronald Dodds')
# classroom(room_name='B-201', morning='IMG5205', invig_morning='Pamela Healey', noon='IMIT1101', invig_noon='Derrick Spence')
# classroom(room_name='C-202', morning='BCCS1102', invig_morning='Valerie Street', noon='IMIT3202', invig_noon='Priscilla Fry')
#
# Day:  Week 1 : Fri
# classroom(room_name='C-002', morning='IMG3204', invig_morning='Muhammed Jackson', noon='BCCS2203', invig_noon='Marta Arnold')
# classroom(room_name='B-201', morning='BCCS1104', invig_morning='Erin Adamson', noon='BCCS2204', invig_noon='Phil Randall')
# classroom(room_name='B-202', morning='IMG1103', invig_morning='Kerri Huynh', noon='IMG2203', invig_noon='Freda Farrell')
# classroom(room_name='C-203', morning='IMG2205', invig_morning='Erin Lee', noon='IMIT5204', invig_noon='Alice Petty')
# classroom(room_name='B-102', morning='BCCS3205', invig_morning='Carolyn Rodgers', noon='IMIT1101', invig_noon='Noreen Jamil')
# classroom(room_name='C-003', morning='IMG3204', invig_morning='Janelle Crow', noon='IMG5205', invig_noon='Bernard Sanford')
# classroom(room_name='B-001', morning='BCCS2202', invig_morning='Nichola Grundy', noon='IMIT4203', invig_noon='Patti Waters')
# classroom(room_name='C-101', morning='IMG3205', invig_morning='Leah Atkins', noon='IMG2202', invig_noon='Vincent Moody')
# classroom(room_name='B-003', morning='BCCS3204', invig_morning='Erin Adamson', noon='IMIT5203', invig_noon='Helene Hassan')
# classroom(room_name='C-004', morning='IMIT3202', invig_morning='David Arias', noon='IMIT5203', invig_noon='Dean Wade')
#
# Day:  Week 1 : Sat
# classroom(room_name='B-102', morning='IMG1103', invig_morning='David Arias', noon='BCCS1103', invig_noon='M Nuttall')
# classroom(room_name='C-002', morning='IMIT1103', invig_morning='Veronica Hooper', noon='BCCS4205', invig_noon='Nadine Barr')
# classroom(room_name='B-104', morning='IMG5204', invig_morning='Josie Shields', noon='IMG2203', invig_noon='Ernie Mullen')
# classroom(room_name='C-201', morning='IMG4205', invig_morning='Millicent Worthington', noon='IMG5205', invig_noon='Bernard Sanford')
# classroom(room_name='B-202', morning='IMG1103', invig_morning='Shaun Hopper', noon='IMIT3202', invig_noon='Hammad Majeed')
# classroom(room_name='B-203', morning='IMIT1104', invig_morning='Clinton Knight', noon='BCCS1103', invig_noon='Veronica Hooper')
# classroom(room_name='B-003', morning='IMG2202', invig_morning='Sidney Nunn', noon='IMIT4203', invig_noon='Janelle Crow')
# classroom(room_name='C-202', morning='BCCS1102', invig_morning='Dora Stanley', noon='IMG2201', invig_noon='Kevan Carter')
#
# Day:  Week 1 : Sun
# classroom(room_name='C-001', morning='IMG2203', invig_morning='Toni Mullins', noon='IMG1105', invig_noon='Katrina James')
# classroom(room_name='C-101', morning='IMIT3201', invig_morning='Bernard Heath', noon='IMG3201', invig_noon='Sunil McLeod')
# classroom(room_name='B-101', morning='BCCS3205', invig_morning='Carl Searle', noon='BCCS4202', invig_noon='Joe Ray')
# classroom(room_name='B-003', morning='IMG2201', invig_morning='Sadie Bradshaw', noon='IMIT4201', invig_noon='Erin Lee')
# classroom(room_name='B-102', morning='BCCS4202', invig_morning='Toni Mullins', noon='IMG4204', invig_noon='Nikki Caldwell')
# classroom(room_name='B-204', morning='IMIT4203', invig_morning='Faisal Cheema', noon='BCCS4205', invig_noon='Jeff Vernon')
# classroom(room_name='C-202', morning='IMIT3202', invig_morning='Katrina James', noon='IMG5205', invig_noon='M Nuttall')
# classroom(room_name='C-201', morning='BCCS4201', invig_morning='Bev Field', noon='IMG1101', invig_noon='Arshad Islam')
# classroom(room_name='C-003', morning='BCCS3205', invig_morning='Jon Curtis', noon='IMIT3204', invig_noon='Derek Ramsey')
# classroom(room_name='C-004', morning='BCCS1102', invig_morning='Phil Randall', noon='IMIT5204', invig_noon='Ira Stevens')
#
# Day:  Week 2 : Mon
# classroom(room_name='B-101', morning='BCCS4204', invig_morning='Tyrone Rayner', noon='IMG4202', invig_noon='Zara Lightfoot')
# classroom(room_name='C-103', morning='IMG3203', invig_morning='Erin Adamson', noon='IMIT1101', invig_noon='Vincent Moody')
# classroom(room_name='B-104', morning='IMIT3202', invig_morning='Aimee Pierson', noon='BCCS4203', invig_noon='David Arias')
# classroom(room_name='B-004', morning='IMG4203', invig_morning='Horace Gardiner', noon='IMIT1105', invig_noon='Sadie Bradshaw')
#
# Day:  Week 2 : Tue
# classroom(room_name='B-201', morning='IMIT5201', invig_morning='Noreen Jamil', noon='IMG2202', invig_noon='Zara Lightfoot')
# classroom(room_name='C-001', morning='IMG1105', invig_morning='Faisal Cheema', noon='IMG2205', invig_noon='Jon Curtis')
# classroom(room_name='C-004', morning='IMG1101', invig_morning='Sheena Butcher', noon='BCCS3203', invig_noon='Horace Gardiner')
# classroom(room_name='B-002', morning='IMIT5205', invig_morning='Anita Lake', noon='IMG3203', invig_noon='Sheena Butcher')
# classroom(room_name='C-102', morning='BCCS4203', invig_morning='Jennie McKenna', noon='BCCS3204', invig_noon='Laurie Castillo')
# classroom(room_name='C-202', morning='IMG1104', invig_morning='Vincent Moody', noon='BCCS4205', invig_noon='Hazel Willis')
# classroom(room_name='C-204', morning='IMIT2202', invig_morning='Aimee Pierson', noon='BCCS2201', invig_noon='Sebastian Lock')
# classroom(room_name='B-204', morning='IMG5203', invig_morning='Mohammad Walter', noon='BCCS3205', invig_noon='Sunil McLeod')
# classroom(room_name='B-202', morning='IMIT5204', invig_morning='Karen Chapman', noon='IMG4205', invig_noon='Karen Chapman')
# classroom(room_name='B-104', morning='IMG3204', invig_morning='Phil Randall', noon='IMG3201', invig_noon='Kerri Huynh')
# classroom(room_name='B-203', morning='IMIT4205', invig_morning='Shoaib Mehboob', noon='BCCS4202', invig_noon='Ira Stevens')
# classroom(room_name='C-003', morning='IMG1102', invig_morning='Sebastian Lock', noon='BCCS1104', invig_noon='Horace Gardiner')
# classroom(room_name='C-203', morning='BCCS4203', invig_morning='Dora Stanley', noon='IMIT4203', invig_noon='Jeff Vernon')
# classroom(room_name='C-201', morning='BCCS4204', invig_morning='Jody Hardman', noon='BCCS3202', invig_noon='Edmund Ford')
# classroom(room_name='C-103', morning='IMG4205', invig_morning='Ira Stevens', noon='BCCS2204', invig_noon='Leah Atkins')
# classroom(room_name='C-104', morning='IMG4205', invig_morning='Debbie Woodward', noon='IMIT1102', invig_noon='Art Goldstein')
# classroom(room_name='B-003', morning='IMG5202', invig_morning='Josie Shields', noon='IMG2205', invig_noon='Jon Curtis')
# classroom(room_name='C-101', morning='BCCS1104', invig_morning='Horace Gardiner', noon='IMG3203', invig_noon='Dianne Foley')
#
# Day:  Week 2 : Wed
# classroom(room_name='C-103', morning='IMG1103', invig_morning='Sadie Bradshaw', noon='IMIT4205', invig_noon='Ernie Mullen')
# classroom(room_name='C-201', morning='IMIT3201', invig_morning='Nichola Grundy', noon='IMG5205', invig_noon='Leah Atkins')
# classroom(room_name='C-102', morning='BCCS2202', invig_morning='Phil Randall', noon='BCCS1101', invig_noon='Farwa Batool')
# classroom(room_name='C-002', morning='IMG5205', invig_morning='Megan Hayward', noon='BCCS3203', invig_noon='Julie Higgins')
# classroom(room_name='B-204', morning='IMIT1104', invig_morning='Paul Winter', noon='BCCS4204', invig_noon='Bryan Hunter')
# classroom(room_name='C-204', morning='BCCS1105', invig_morning='Alex Sweeney', noon='IMG4201', invig_noon='Hassan Mustafa')
# classroom(room_name='B-003', morning='BCCS4202', invig_morning='Doris Slaughter', noon='IMIT2201', invig_noon='Colin Madden')
# classroom(room_name='B-102', morning='IMIT3202', invig_morning='Veronica Hooper', noon='IMG3204', invig_noon='Daphne Rutherford')
# classroom(room_name='B-202', morning='IMG1102', invig_morning='Valerie Street', noon='BCCS1103', invig_noon='Jeff Vernon')
# classroom(room_name='C-004', morning='IMG5203', invig_morning='Zeeshan Qaiser', noon='IMIT2205', invig_noon='Dianne Foley')
# classroom(room_name='B-203', morning='IMIT4205', invig_morning='Alicia Kane', noon='BCCS2205', invig_noon='Bernard Sanford')
# classroom(room_name='C-101', morning='IMIT4204', invig_morning='Bev Field', noon='BCCS1104', invig_noon='Behjat Zuhaira')
# classroom(room_name='B-001', morning='BCCS4203', invig_morning='Ali Hurley', noon='IMG3202', invig_noon='Erin Adamson')
# classroom(room_name='C-003', morning='IMG2201', invig_morning='Alicia Kane', noon='IMG4205', invig_noon='Andre Holder')
# classroom(room_name='C-202', morning='IMG4205', invig_morning='Tayyaba Zainab', noon='BCCS1101', invig_noon='Josie Shields')
#
# Day:  Week 2 : Thu
# classroom(room_name='B-002', morning='BCCS3202', invig_morning='Bridget Haynes', noon='IMIT5205', invig_noon='Julie Higgins')
# classroom(room_name='B-204', morning='BCCS1104', invig_morning='Kyle Noble', noon='IMG4205', invig_noon='Behjat Zuhaira')
# classroom(room_name='B-201', morning='IMG4205', invig_morning='Alice Petty', noon='IMIT5202', invig_noon='Aimee Pierson')
# classroom(room_name='C-102', morning='IMIT3202', invig_morning='Josie Shields', noon='IMIT2201', invig_noon='Edmund Ford')
# classroom(room_name='B-103', morning='BCCS1103', invig_morning='Toni Mullins', noon='IMIT5203', invig_noon='Jennie McKenna')
# classroom(room_name='B-104', morning='IMIT4201', invig_morning='Alex Sweeney', noon='BCCS1103', invig_noon='Ira Stevens')
# classroom(room_name='B-102', morning='IMIT1105', invig_morning='Jon Curtis', noon='IMIT4202', invig_noon='Millicent Worthington')
# classroom(room_name='C-202', morning='IMIT3202', invig_morning='Carolyn Rodgers', noon='IMG3203', invig_noon='Clinton Knight')
# classroom(room_name='C-101', morning='BCCS3204', invig_morning='Derrick Spence', noon='IMG2203', invig_noon='Farwa Batool')
# classroom(room_name='C-003', morning='BCCS4201', invig_morning='Andre Holder', noon='BCCS2201', invig_noon='Judy Betts')
# classroom(room_name='C-001', morning='BCCS2205', invig_morning='Veronica Hooper', noon='IMIT4202', invig_noon='Dianne Foley')
# classroom(room_name='B-202', morning='IMG1103', invig_morning='Anita Lake', noon='IMG2202', invig_noon='Pamela Healey')
# classroom(room_name='C-204', morning='IMG5203', invig_morning='Janelle Crow', noon='IMG5205', invig_noon='Erin Lee')
#
# Day:  Week 2 : Fri
# classroom(room_name='C-203', morning='IMIT1101', invig_morning='Nadine Barr', noon='BCCS1104', invig_noon='Josie Shields')
# classroom(room_name='B-001', morning='IMG1104', invig_morning='Arshad Islam', noon='BCCS4204', invig_noon='Ernie Mullen')
# classroom(room_name='C-202', morning='BCCS3202', invig_morning='Helene Hassan', noon='BCCS4202', invig_noon='Farwa Batool')
# classroom(room_name='B-003', morning='IMG2205', invig_morning='Jody Hardman', noon='IMG5203', invig_noon='Sidney Nunn')
# classroom(room_name='B-104', morning='IMIT5204', invig_morning='Art Goldstein', noon='IMIT5202', invig_noon='Carolyn Rodgers')
# classroom(room_name='C-101', morning='IMIT3205', invig_morning='Shoaib Mehboob', noon='BCCS3202', invig_noon='Behjat Zuhaira')
# classroom(room_name='C-002', morning='IMG1102', invig_morning='Bernard Heath', noon='IMG5202', invig_noon='Leah Atkins')
# classroom(room_name='C-003', morning='IMG5203', invig_morning='Dominic Atkinson', noon='IMG4203', invig_noon='Janelle Crow')
#
# Day:  Week 2 : Sat
# classroom(room_name='B-102', morning='IMIT2203', invig_morning='Nikki Caldwell', noon='IMIT5205', invig_noon='Doris Slaughter')
# classroom(room_name='C-203', morning='IMIT5204', invig_morning='Jen Sloan', noon='IMG3204', invig_noon='Zeeshan Qaiser')
# classroom(room_name='C-101', morning='IMG2205', invig_morning='Derrick Spence', noon='IMG5201', invig_noon='Behjat Zuhaira')
# classroom(room_name='B-204', morning='IMG1102', invig_morning='Shoaib Mehboob', noon='BCCS2203', invig_noon='Sebastian Lock')
# classroom(room_name='B-101', morning='BCCS2201', invig_morning='Cesar Harper', noon='IMG3205', invig_noon='Kerri Huynh')
# classroom(room_name='B-201', morning='IMG5201', invig_morning='Daphne Rutherford', noon='BCCS3203', invig_noon='Laurie Castillo')
# classroom(room_name='B-003', morning='IMIT2204', invig_morning='Noor ul Ain', noon='BCCS2202', invig_noon='Darla Hicks')
# classroom(room_name='C-102', morning='IMG3201', invig_morning='Jody Hardman', noon='IMG4205', invig_noon='Kevan Carter')
# classroom(room_name='C-201', morning='IMIT2205', invig_morning='Irene Ramirez', noon='IMIT3205', invig_noon='Alicia Kane')
# classroom(room_name='C-003', morning='IMIT1103', invig_morning='Arshad Islam', noon='BCCS2202', invig_noon='Bryan Hunter')
# classroom(room_name='B-002', morning='BCCS3201', invig_morning='Kevan Carter', noon='IMG3203', invig_noon='Tyrone Rayner')
# classroom(room_name='C-002', morning='BCCS2205', invig_morning='Clinton Knight', noon='IMIT3202', invig_noon='Horace Gardiner')
# classroom(room_name='C-202', morning='IMG5205', invig_morning='Aimee Pierson', noon='IMG1103', invig_noon='Dominic Atkinson')
# classroom(room_name='B-202', morning='IMIT1105', invig_morning='Young Pitts', noon='BCCS2201', invig_noon='Art Goldstein')
#
# Day:  Week 2 : Sun
# classroom(room_name='B-102', morning='IMG3204', invig_morning='Aimee Pierson', noon='IMG5202', invig_noon='Daphne Rutherford')
# classroom(room_name='C-004', morning='IMIT1102', invig_morning='Derrick Spence', noon='IMG3203', invig_noon='Jennie McKenna')
# classroom(room_name='C-201', morning='BCCS2205', invig_morning='Sadie Bradshaw', noon='BCCS1103', invig_noon='Ali Hurley')
# classroom(room_name='B-202', morning='IMIT2203', invig_morning='Julie Higgins', noon='BCCS1103', invig_noon='Vincent Moody')
#
# ---------------------------------
#
# Hard constraints:
#
# hc1 =  1.0  hc2 =  1.0  hc3 =  0.125  hc4 =  0.045454545454545456  sc2 =  0.06666666666666667
# An exam will be scheduled for each course: ✅
# A student cannot give more than 1 exam at a time: ✅
# A teacher cannot invigilate two exams at the same time: ✖
# Each course is scheduled atleast once: ✖
#
#
# Soft constraints:
#
# Equal number of invigilation duties: ✅
# Schedule in less days: ✖
#
#
# 0 - Fitness of best solution:  3.2371212121212123 	( Fitness of local best solution:  3.2371212121212123 ) 	( Stagnation:  0 )
# 1 - Fitness of best solution:  3.264423076923077 	( Fitness of local best solution:  3.264423076923077 ) 	( Stagnation:  0 )
# 2 - Fitness of best solution:  3.2753357753357752 	( Fitness of local best solution:  3.2753357753357752 ) 	( Stagnation:  0 )
# 3 - Fitness of best solution:  3.317099567099567 	( Fitness of local best solution:  3.317099567099567 ) 	( Stagnation:  0 )
# 4 - Fitness of best solution:  3.317099567099567 	( Fitness of local best solution:  3.317099567099567 ) 	( Stagnation:  1 )
# 5 - Fitness of best solution:  3.3686868686868685 	( Fitness of local best solution:  3.3686868686868685 ) 	( Stagnation:  0 )
# 6 - Fitness of best solution:  3.3686868686868685 	( Fitness of local best solution:  3.3686868686868685 ) 	( Stagnation:  1 )
# 7 - Fitness of best solution:  3.4095238095238094 	( Fitness of local best solution:  3.4095238095238094 ) 	( Stagnation:  0 )
# 8 - Fitness of best solution:  3.4095238095238094 	( Fitness of local best solution:  3.4095238095238094 ) 	( Stagnation:  1 )
# 9 - Fitness of best solution:  3.4095238095238094 	( Fitness of local best solution:  3.4095238095238094 ) 	( Stagnation:  2 )
# 10 - Fitness of best solution:  3.4575757575757575 	( Fitness of local best solution:  3.4575757575757575 ) 	( Stagnation:  0 )
# 11 - Fitness of best solution:  3.466666666666667 	( Fitness of local best solution:  3.466666666666667 ) 	( Stagnation:  0 )
# 12 - Fitness of best solution:  3.5500000000000003 	( Fitness of local best solution:  3.5500000000000003 ) 	( Stagnation:  0 )
# 13 - Fitness of best solution:  4.138888888888889 	( Fitness of local best solution:  4.138888888888889 ) 	( Stagnation:  0 )
# 14 - Fitness of best solution:  4.138888888888889 	( Fitness of local best solution:  4.138888888888889 ) 	( Stagnation:  1 )
# 15 - Fitness of best solution:  4.15530303030303 	( Fitness of local best solution:  4.15530303030303 ) 	( Stagnation:  0 )
# 16 - Fitness of best solution:  4.15530303030303 	( Fitness of local best solution:  4.15530303030303 ) 	( Stagnation:  1 )
# 17 - Fitness of best solution:  4.15530303030303 	( Fitness of local best solution:  4.15530303030303 ) 	( Stagnation:  2 )
# 18 - Fitness of best solution:  4.157258064516129 	( Fitness of local best solution:  4.157258064516129 ) 	( Stagnation:  0 )
# 19 - Fitness of best solution:  4.1594827586206895 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  0 )
# 20 - Fitness of best solution:  4.1594827586206895 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  1 )
# 21 - Fitness of best solution:  4.1594827586206895 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  2 )
# 22 - Fitness of best solution:  4.1594827586206895 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  3 )
# 23 - Fitness of best solution:  4.162037037037037 	( Fitness of local best solution:  4.162037037037037 ) 	( Stagnation:  0 )
# 24 - Fitness of best solution:  4.162037037037037 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  1 )
# 25 - Fitness of best solution:  4.162037037037037 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  2 )
# 26 - Fitness of best solution:  4.162037037037037 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  3 )
# 27 - Fitness of best solution:  4.162037037037037 	( Fitness of local best solution:  4.1594827586206895 ) 	( Stagnation:  4 )
# 28 - Fitness of best solution:  4.162037037037037 	( Fitness of local best solution:  4.162037037037037 ) 	( Stagnation:  5 )
# 29 - Fitness of best solution:  4.162037037037037 	( Fitness of local best solution:  4.162037037037037 ) 	( Stagnation:  6 )
# 30 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  0 )
# 31 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  1 )
# 32 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  2 )
# 33 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  3 )
# 34 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  4 )
# 35 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  5 )
# 36 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  6 )
# 37 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  7 )
# 38 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  8 )
# 39 - Fitness of best solution:  4.166666666666667 	( Fitness of local best solution:  4.166666666666667 ) 	( Stagnation:  9 )
# 40 - Fitness of best solution:  4.170454545454545 	( Fitness of local best solution:  4.170454545454545 ) 	( Stagnation:  0 )
# 41 - Fitness of best solution:  4.170454545454545 	( Fitness of local best solution:  4.170454545454545 ) 	( Stagnation:  1 )
# 42 - Fitness of best solution:  4.170454545454545 	( Fitness of local best solution:  4.170454545454545 ) 	( Stagnation:  2 )
# 43 - Fitness of best solution:  4.170454545454545 	( Fitness of local best solution:  4.170454545454545 ) 	( Stagnation:  3 )
# 44 - Fitness of best solution:  4.170454545454545 	( Fitness of local best solution:  4.170454545454545 ) 	( Stagnation:  4 )
# 45 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  0 )
# 46 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  1 )
# 47 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  2 )
# 48 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  3 )
# 49 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  4 )
# 50 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  5 )
# 51 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  6 )
# 52 - Fitness of best solution:  4.1726190476190474 	( Fitness of local best solution:  4.1726190476190474 ) 	( Stagnation:  7 )
# 53 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  0 )
# 54 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  1 )
# 55 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  2 )
# 56 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  3 )
# 57 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  4 )
# 58 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  5 )
# 59 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  6 )
# 60 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  7 )
# 61 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  8 )
# 62 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  9 )
# 63 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  10 )
# 64 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  11 )
# 65 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  12 )
# 66 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  13 )
# 67 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  14 )
# 68 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  15 )
# 69 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  16 )
# 70 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  17 )
# 71 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  18 )
# 72 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  19 )
# 73 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  20 )
# 74 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  21 )
# 75 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  22 )
# 76 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  23 )
# 77 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  24 )
# 78 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  25 )
# 79 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  26 )
# 80 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  27 )
# 81 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  28 )
# 82 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  29 )
# 83 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  30 )
# 84 - Fitness of best solution:  4.175 	( Fitness of local best solution:  4.175 ) 	( Stagnation:  31 )
# 85 - Fitness of best solution:  4.177631578947368 	( Fitness of local best solution:  4.177631578947368 ) 	( Stagnation:  0 )
# 86 - Fitness of best solution:  4.177631578947368 	( Fitness of local best solution:  4.177631578947368 ) 	( Stagnation:  1 )
# 87 - Fitness of best solution:  4.177631578947368 	( Fitness of local best solution:  4.177631578947368 ) 	( Stagnation:  2 )
# 88 - Fitness of best solution:  4.177631578947368 	( Fitness of local best solution:  4.177631578947368 ) 	( Stagnation:  3 )
# 89 - Fitness of best solution:  4.177631578947368 	( Fitness of local best solution:  4.177631578947368 ) 	( Stagnation:  4 )
# 90 - Fitness of best solution:  4.177777777777777 	( Fitness of local best solution:  4.177777777777777 ) 	( Stagnation:  0 )
# 91 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  0 )
# 92 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  1 )
# 93 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  2 )
# 94 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  3 )
# 95 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  4 )
# 96 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  5 )
# 97 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  6 )
# 98 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  7 )
# 99 - Fitness of best solution:  4.180555555555555 	( Fitness of local best solution:  4.180555555555555 ) 	( Stagnation:  8 )
# Current generation so far:  100
# Best solution so far:
# Fitness:  4.1838235294117645
#
# Day:  Week 1 : Wed
# classroom(room_name='B-204', morning='BCCS4203', invig_morning='Mohammad Walter', noon='IMIT3202', invig_noon='Freda Farrell')
# classroom(room_name='C-002', morning='IMIT1102', invig_morning='Veronica Hooper', noon='BCCS2203', invig_noon='Julie Higgins')
# classroom(room_name='B-101', morning='BCCS3204', invig_morning='Paul Winter', noon='IMG5203', invig_noon='Christine Tompkins')
# classroom(room_name='C-204', morning='IMG5204', invig_morning='Laurie Castillo', noon='IMIT2201', invig_noon='Alex Sweeney')
#
# Day:  Week 1 : Sat
# classroom(room_name='C-202', morning='BCCS2205', invig_morning='Aurora Terry', noon='IMG4203', invig_noon='Dominic Atkinson')
# classroom(room_name='C-004', morning='IMIT3203', invig_morning='Hammad Majeed', noon='IMIT3204', invig_noon='David Arias')
# classroom(room_name='B-001', morning='BCCS1101', invig_morning='Bryan Hunter', noon='IMG4205', invig_noon='Sidney Nunn')
# classroom(room_name='B-204', morning='IMG3201', invig_morning='Tyrone Rayner', noon='IMG2204', invig_noon='Jody Hardman')
#
# Day:  Week 1 : Sun
# classroom(room_name='B-203', morning='IMG1104', invig_morning='Shoaib Mehboob', noon='IMG2201', invig_noon='Christine Tompkins')
# classroom(room_name='B-003', morning='BCCS4204', invig_morning='Erin Adamson', noon='IMG4204', invig_noon='Laurie Castillo')
# classroom(room_name='C-002', morning='IMIT1101', invig_morning='Mitchell Walter', noon='IMIT3205', invig_noon='Derrick Spence')
#
# Day:  Week 2 : Wed
# classroom(room_name='B-001', morning='IMIT2204', invig_morning='Jon Curtis', noon='BCCS4203', invig_noon='Alistair Ashley')
# classroom(room_name='B-204', morning='IMG5201', invig_morning='Christine Tompkins', noon='IMG2203', invig_noon='Eric Humphries')
# classroom(room_name='C-104', morning='IMG4202', invig_morning='Megan Hayward', noon='IMG4205', invig_noon='Freda Farrell')
# classroom(room_name='B-103', morning='IMIT3204', invig_morning='Jeffery Perez', noon='IMIT5204', invig_noon='Phil Randall')
#
# Day:  Week 2 : Thu
# classroom(room_name='B-002', morning='BCCS3202', invig_morning='Bridget Haynes', noon='IMIT5205', invig_noon='Julie Higgins')
# classroom(room_name='B-204', morning='BCCS1104', invig_morning='Kyle Noble', noon='IMG4205', invig_noon='Behjat Zuhaira')
# classroom(room_name='B-201', morning='BCCS1103', invig_morning='Katrina James', noon='IMIT5202', invig_noon='Jeffery Perez')
# classroom(room_name='C-102', morning='IMIT3201', invig_morning='Faisal Cheema', noon='BCCS4205', invig_noon='Sidney Nunn')
# classroom(room_name='B-103', morning='BCCS3201', invig_morning='Irene Ramirez', noon='IMIT4205', invig_noon='Bryan Hunter')
# classroom(room_name='B-104', morning='IMIT4201', invig_morning='Alex Sweeney', noon='BCCS1103', invig_noon='Ira Stevens')
# classroom(room_name='B-102', morning='IMIT1105', invig_morning='Jon Curtis', noon='IMIT4202', invig_noon='Millicent Worthington')
# classroom(room_name='C-202', morning='IMIT3202', invig_morning='Carolyn Rodgers', noon='IMG3203', invig_noon='Clinton Knight')
# classroom(room_name='C-101', morning='BCCS3202', invig_morning='Toni Mullins', noon='IMG1102', invig_noon='Jeremy Romero')
# classroom(room_name='C-003', morning='BCCS4201', invig_morning='Andre Holder', noon='BCCS2201', invig_noon='Judy Betts')
# classroom(room_name='C-001', morning='BCCS2205', invig_morning='Veronica Hooper', noon='IMIT4202', invig_noon='Dianne Foley')
# classroom(room_name='B-202', morning='IMG1103', invig_morning='Anita Lake', noon='IMG2202', invig_noon='Pamela Healey')
# classroom(room_name='C-204', morning='BCCS2202', invig_morning='Christine Tompkins', noon='BCCS3202', invig_noon='Jeff Vernon')
#
# Day:  Week 2 : Fri
# classroom(room_name='C-002', morning='IMIT3205', invig_morning='Jeremy Romero', noon='IMG3202', invig_noon='Carolyn Rodgers')
# classroom(room_name='C-004', morning='IMG3205', invig_morning='Ronald Dodds', noon='IMG2204', invig_noon='Mohammad Walter')
# classroom(room_name='B-104', morning='IMIT5201', invig_morning='Kevan Carter', noon='BCCS1105', invig_noon='Sebastian Lock')
# classroom(room_name='B-003', morning='IMIT5205', invig_morning='Anita Lake', noon='BCCS2203', invig_noon='Erin Adamson')
#
# Day:  Week 2 : Sun
# classroom(room_name='C-001', morning='BCCS2204', invig_morning='Jess Shah', noon='IMG2205', invig_noon='Faisal Cheema')
# classroom(room_name='B-101', morning='IMG5201', invig_morning='Andrew Lawton', noon='IMIT5204', invig_noon='Marta Arnold')
# classroom(room_name='C-003', morning='IMIT5202', invig_morning='Katrina James', noon='BCCS2204', invig_noon='Bertha Cummins')
# classroom(room_name='C-201', morning='IMIT1104', invig_morning='Julie Higgins', noon='IMG5202', invig_noon='Edmund Ford')
#
# ---------------------------------
#
# Hard constraints:
#
# hc1 =  0.058823529411764705  hc2 =  1.0  hc3 =  1.0  hc4 =  1.0  sc2 =  0.125
# An exam will be scheduled for each course: ✖
# A student cannot give more than 1 exam at a time: ✅
# A teacher cannot invigilate two exams at the same time: ✅
# Each course is scheduled atleast once: ✅
#
#
# Soft constraints:
#
# Equal number of invigilation duties: ✅
# Schedule in less days: ✅
#
#
# 100 - Fitness of best solution:  4.1838235294117645 	( Fitness of local best solution:  4.1838235294117645 ) 	( Stagnation:  0 )
# 101 - Fitness of best solution:  4.190909090909091 	( Fitness of local best solution:  4.190909090909091 ) 	( Stagnation:  0 )
# 102 - Fitness of best solution:  4.190909090909091 	( Fitness of local best solution:  4.190909090909091 ) 	( Stagnation:  1 )
# 103 - Fitness of best solution:  4.194444444444445 	( Fitness of local best solution:  4.194444444444445 ) 	( Stagnation:  0 )
# 104 - Fitness of best solution:  4.194444444444445 	( Fitness of local best solution:  4.194444444444445 ) 	( Stagnation:  1 )
# 105 - Fitness of best solution:  4.194444444444445 	( Fitness of local best solution:  4.194444444444445 ) 	( Stagnation:  2 )
# 106 - Fitness of best solution:  4.194444444444445 	( Fitness of local best solution:  4.194444444444445 ) 	( Stagnation:  3 )
# 107 - Fitness of best solution:  4.194444444444445 	( Fitness of local best solution:  4.194444444444445 ) 	( Stagnation:  4 )
# 108 - Fitness of best solution:  4.21978021978022 	( Fitness of local best solution:  4.21978021978022 ) 	( Stagnation:  0 )
# 109 - Fitness of best solution:  4.21978021978022 	( Fitness of local best solution:  4.21978021978022 ) 	( Stagnation:  1 )
# 110 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  0 )
# 111 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  1 )
# 112 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  2 )
# 113 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  3 )
# 114 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  4 )
# 115 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  5 )
# 116 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  6 )
# 117 - Fitness of best solution:  4.271428571428572 	( Fitness of local best solution:  4.271428571428572 ) 	( Stagnation:  7 )
# 118 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  0 )
# 119 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  1 )
# 120 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  2 )
# 121 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  3 )
# 122 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  4 )
# 123 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  5 )
# 124 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  6 )
# 125 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  7 )
# 126 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  8 )
# 127 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  9 )
# 128 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  10 )
# 129 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  11 )
# 130 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  12 )
# 131 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  13 )
# 132 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  14 )
# 133 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  15 )
# 134 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  16 )
# 135 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  17 )
# 136 - Fitness of best solution:  4.316666666666666 	( Fitness of local best solution:  4.316666666666666 ) 	( Stagnation:  18 )
# 137 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  0 )
# 138 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  1 )
# 139 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  2 )
# 140 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  3 )
# 141 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  4 )
# 142 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  5 )
# 143 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  6 )
# 144 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  7 )
# 145 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  8 )
# 146 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  9 )
# 147 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  10 )
# 148 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  11 )
# 149 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  12 )
# 150 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  13 )
# 151 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  14 )
# 152 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  15 )
# 153 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  16 )
# 154 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  17 )
# 155 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  18 )
# 156 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  19 )
# 157 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  20 )
# 158 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  21 )
# 159 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  22 )
# 160 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  23 )
# 161 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  24 )
# 162 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  25 )
# 163 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  26 )
# 164 - Fitness of best solution:  4.321428571428571 	( Fitness of local best solution:  4.321428571428571 ) 	( Stagnation:  27 )
# 165 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  0 )
# 166 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  1 )
# 167 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  2 )
# 168 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  3 )
# 169 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  4 )
# 170 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  5 )
# 171 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  6 )
# 172 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  7 )
# 173 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  8 )
# 174 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  9 )
# 175 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  10 )
# 176 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  11 )
# 177 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  12 )
# 178 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  13 )
# 179 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  14 )
# 180 - Fitness of best solution:  4.404761904761905 	( Fitness of local best solution:  4.404761904761905 ) 	( Stagnation:  15 )
#
#
#                                Week 1 : Mon
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    C-004    IMIT3202    Paul Winter           BCCS4202    Horace Gardiner
#    B-104    IMIT1103    Zeeshan Qaiser        IMG4203    Usman Dobson
#    C-103    BCCS3205    Kyle Noble            BCCS1102    Millicent Worthington
#    C-001    IMIT5205    Alicia Kane           BCCS2202    Ira Stevens
#
#
#                                Week 1 : Tue
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    C-103    IMG5201    Toni Mullins          IMG4201    Nadine Barr
#    C-204    IMG2205    Dianne Foley          IMG5202    Julie Higgins
#    C-104    IMIT4203    Kashif Munir          IMG2201    Freda Farrell
#
#
#                                Week 1 : Wed
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    B-204    BCCS4203    Mohammad Walter       IMIT3202    Freda Farrell
#    C-002    IMIT1102    Veronica Hooper       BCCS2203    Julie Higgins
#    B-101    BCCS3204    Paul Winter           IMG5203    Christine Tompkins
#    C-204    IMG5204    Laurie Castillo       IMIT2201    Alex Sweeney
#
#
#                                Week 1 : Thu
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    B-202    IMG3204    Patti Waters          BCCS2201    Valerie Street
#    C-203    IMG1104    Hassan Mustafa        IMIT5204    Tayyaba Zainab
#    B-104    IMG4204    Josie Shields         IMIT2203    Horace Gardiner
#    C-003    IMIT5204    Noreen Jamil          IMG2205    Ira Stevens
#
#
#                                Week 1 : Fri
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    B-003    BCCS1101    Bertha Cummins        IMIT4202    Erin Adamson
#    C-203    IMG1103    Clinton Knight        IMG1101    Ali Hurley
#    B-004    IMG3201    Patti Waters          BCCS3203    Erin Lee
#
#
#                                Week 1 : Sat
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    C-202    BCCS2205    Aurora Terry          IMG4203    Dominic Atkinson
#    C-004    IMIT3203    Hammad Majeed         IMIT3204    David Arias
#    B-001    BCCS1101    Bryan Hunter          IMG4205    Sidney Nunn
#    B-204    IMG3201    Tyrone Rayner         IMG2204    Jody Hardman
#
#
#                                Week 1 : Sun
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    B-203    IMG1105    Faisal Cheema         BCCS3203    Aimee Pierson
#    B-003    BCCS4204    Erin Adamson          IMG4204    Laurie Castillo
#    C-002    IMIT1101    Mitchell Walter       IMIT3205    Derrick Spence
#
#
#                                Week 2 : Mon
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    C-201    IMIT4204    Bertha Cummins        IMIT2204    Karen Chapman
#    C-001    IMIT5202    Jon Curtis            IMIT3205    Andrew Lawton
#    B-203    IMIT4202    Karen Chapman         IMIT2202    Jeremy Romero
#    C-101    IMG1103    Janelle Crow          IMIT5201    Bev Field
#
#
#                                Week 2 : Wed
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    B-001    BCCS2203    Alice Petty           BCCS2205    Alex Sweeney
#    B-204    IMG5201    Christine Tompkins    IMG2203    Eric Humphries
#    C-104    IMG4202    Tyrone Rayner         IMG4202    Pamela Healey
#    B-103    IMG1103    Ali Hurley            BCCS1104    Doris Slaughter
#
#
#                                Week 2 : Thu
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    B-002    BCCS3202    Bridget Haynes        IMIT5205    Julie Higgins
#    B-204    BCCS1104    Kyle Noble            IMG4205    Behjat Zuhaira
#    B-201    BCCS1103    Katrina James         IMIT5202    Jeffery Perez
#    C-102    IMIT3201    Faisal Cheema         BCCS4205    Sidney Nunn
#    B-103    BCCS3201    Irene Ramirez         IMIT4205    Bryan Hunter
#    B-104    IMIT4201    Alex Sweeney          BCCS1103    Ira Stevens
#    B-102    IMIT1105    Jon Curtis            IMIT4202    Millicent Worthington
#    C-202    IMIT3202    Carolyn Rodgers       IMG3203    Clinton Knight
#    C-101    BCCS3202    Toni Mullins          IMG1102    Jeremy Romero
#    C-003    BCCS4201    Andre Holder          BCCS2201    Judy Betts
#    C-001    BCCS2205    Veronica Hooper       IMIT4202    Dianne Foley
#    B-202    IMG1103    Anita Lake            IMG2202    Pamela Healey
#    C-204    BCCS2202    Christine Tompkins    BCCS3202    Jeff Vernon
#
#
#                                Week 2 : Fri
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    C-002    IMIT3205    Jeremy Romero         IMG3202    Carolyn Rodgers
#    C-004    IMG3205    Ronald Dodds          IMG2204    Mohammad Walter
#    B-104    IMIT5201    Kevan Carter          BCCS1105    Sebastian Lock
#    B-003    IMIT5205    Anita Lake            BCCS2203    Erin Adamson
#
#
#                                Week 2 : Sat
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    C-202    IMG3203    Julie Higgins         IMIT2205    Eric Humphries
#    B-104    IMIT2204    Paul Winter           IMIT2201    Nadine Barr
#
#
#                                Week 2 : Sun
#
#
#  Room No   9 - 12    Morning Invigilator   2 - 5     Evening Invigilator
#
#    C-001    BCCS2204    Jess Shah             IMG2205    Faisal Cheema
#    B-101    IMG2203    Mitchell Walter       IMIT1103    Muhammad Asim
#    C-003    IMG3204    Alex Sweeney          BCCS2205    Edna Todd
#    C-201    IMIT1104    Priscilla Fry         IMG5204    Cesar Harper
#
#                              HARD CONSTRAINTS
#
#   1: Exam is scheduled for each course = ✅✅
#   2: Student cannot give more than one exam at a time = ✅✅
#   3: Teacher invigilates one exam at a time = ✅✅
#   4: Exam wont be held on weekends = ✅✅
#   5: Use at max 24 classrooms = ✅✅
#
#
#                              SOFT CONSTRAINTS
#
#   1: Exam is scheduled in less days = ✅✅
#   2: Almost equal number of invigilation duties = ✅✅
